# %%
import pandas as pd

# %%
kwd = pd.read_csv('../data/kwd.csv',header=1)
kwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29031 entries, 0 to 29030
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   일별               29031 non-null  object
#  1   캠페인              29031 non-null  object
#  2   광고그룹             29031 non-null  object
#  3   키워드              29031 non-null  object
#  4   PC/모바일 매체        29031 non-null  object
#  5   노출수              29031 non-null  int64
#  6   클릭수              29031 non-null  int64
#  7   클릭률(%)           29031 non-null  float64
#  8   평균클릭비용(VAT포함,원)  29031 non-null  int64
#  9   총비용(VAT포함,원)     29031 non-null  int64
#  10  평균노출순위           29031 non-null  float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.4+ MB

# %%
kwd
# Out:
#                 일별                  캠페인              광고그룹       키워드 PC/모바일 매체  \
# 0      2025.08.06.  #2파워링크  메인키워드 재셋팅PC             메인키워드         -        PC
# 1      2025.08.07.  #2파워링크  메인키워드 재셋팅PC             메인키워드         -        PC
# 2      2025.08.08.  #2파워링크  메인키워드 재셋팅PC             메인키워드         -        PC
# 3      2025.08.09.  #2파워링크  메인키워드 재셋팅PC             메인키워드         -        PC
# 4      2025.08.10.  #2파워링크  메인키워드 재셋팅PC             메인키워드         -        PC
# ...            ...                  ...               ...       ...       ...
# 29026  2025.08.19.           파워링크250507  지역_사당_파워링크250526   사당턱관절병원       모바일
# 29027  2025.08.24.           파워링크250507  지역_사당_파워링크250526   사당턱관절병원       모바일
# 29028  2025.08.27.           파워링크250507  지역_사당_파워링크250526   사당턱관절병원       모바일
# 29029  2025.08.28.           파워링크250507  지역_사당_파워링크250526  사당턱관절보톡스       모바일
# 29030  2025.10.10.           파워링크250507  지역_사당_파워링크250526   사당턱관절치료       모바일
#
# ...

# %%
pd.read_csv('../data/info_smlog.csv').loc[0][0]
# Out:
# /var/folders/pj/56vfckbx1xl650_vz494zrk00000gn/T/ipykernel_35947/1498390745.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pd.read_csv('../data/info_smlog.csv').loc[0][0]
# 'yoonnam220'
